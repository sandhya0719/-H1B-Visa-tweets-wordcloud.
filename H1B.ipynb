# %% [markdown]
# # H1B visa rules

# %% [markdown]
# ### The H-1B is a non-immigrant visa in the United States under the Immigration and Nationality Act, section 101(a)(17)(H). It allows U.S. employers to temporarily employ foreign workers in specialty occupations.

# %% [markdown]
# #### What are the proposed changes to H-1B visa norms?
#
# Different bills proposed by senators have lobbied for reforms in the H-1B and L-1 visa norms. Some of the proposed changes are:
#
# •Doubling minimum salaries of H-1B visa holders to $130,000
#
# •Earmark 20% of H-1B visas for small and start-up employers
#
# •Remove ‘per country’ cap for employment visas to ensure equal distribution
#
# •Firms hiring H-1B visa holders need to make a “good faith” effort to recruit Americans first
#
# •Give preference to students educated in the US for H-1B visas rather than computerized lottery system
#
# •Crack down on outsourcing companies that import workers for temporary training and then send them back home to do the same job
#
# •Prohibit spouses of H-1B visa holders from working in the US
#
# •Prohibit companies with more than 50 employees, of which at least half are H-1B or L-1 holders, from hiring additional H-1B employees
#
# •Strict audit and vetting by Department of Labor to clamp down on fraud or misuse

# %% [markdown]
# #### How does this affect India?
#
# The biggest beneficiaries of H-1B visas are Indians, followed by the Chinese. In 2014, 70% of total H-1B petitions approved were from Indians
#
# Nearly 86% of the H-1B visas issued for workers in computer occupations go to Indian workers, according to a Computerworld analysis of government data obtained through a Freedom of Information Act request.
#
# Indian outsourcing firms such as Infosys, Wipro, Tata Consultancy Services will be badly hit. In reaction to the news, stock prices of information technology companies fell by 9%.
#
# TCS and Infosys are already battling lawsuits in federal courts that allege that they discriminate against American workers while hiring and favour South Asians.

# %% [markdown]
# So, here i created a Word cloud from tweets of h1b

# %%
import tweepy
import csv
import pandas as pd
from tweepy import  *

# %%
consumer_key = 'ndu0zVJbtqslYmE5Pa8oBO64M'
consumer_secret = 'xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx'
access_token = '721006141430374400-3pIqufcl8LBlfhgGE9HGe97E2v1QtE9'
access_secret = 'xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx'
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

# %%
api = tweepy.API(auth)

# %%
# Open/Create a file to append data
csvFile = open('tweets1.csv', 'a')
#Use csv Writer
csvWriter = csv.writer(csvFile)

# %%
for tweet1 in tweepy.Cursor(api.search,q="#H1B",count=100,\
                           lang="en",\
                           since_id=2017-01-24).items():
    print tweet1.text
    csvWriter.writerow([tweet1.text.encode('utf-8')])
# Out:
# https://t.co/e0PYT2kKv8 @arora_pravir of @aptechltd shares his views on #H1B visa
# Greetings from MVM Infotech
#
# We are looking for #H1B transfer in Java, .NET, Ruby on Ra https://t.co/R1uUUJyypp https://t.co/v9BJz3vKJN
# Greetings from MVM Infotech
#
# We are looking for #H1B transfer in Java, .NET, Rub https://t.co/fU080O68wM
# Greetings from MVM Infotech
#
# We are looking for #H1B transfer in Java, .NET, Ruby on Ra https://t.co/R1uUUJyypp
# Greetings from MVM Infotech
#
# We are looking for #H1B transfer in Java, .NET, Ruby on Rails and
# Hyperion.
#
# About... https://t.co/mUa2yZaFl8
# Greetings from MVM Infotech
#
# We are looking for #H1B transfer in Java, .NET, Ruby on Rails and
# Hyperion.
#
# About... https://t.co/acAEKLttD6
# #H1B #visa reforms pose challenges but to benefit Indian economy: Former ambassador
# https://t.co/6g58496fnx… https://t.co/N6cPlw4oNt
# #Boomlive highlights RHC founder @iamshalabhkumar's optimistic take on #H1B visas
# https://t.co/Q9hMyrqtTN
# ...

# %%
df = pd.read_csv('tweets1.csv',quoting=csv.QUOTE_NONE,error_bad_lines=False)
# Out:
# Skipping line 5: expected 1 fields, saw 3
# Skipping line 9: expected 1 fields, saw 3
# Skipping line 13: expected 1 fields, saw 3
# Skipping line 17: expected 1 fields, saw 3
# Skipping line 24: expected 1 fields, saw 3
# Skipping line 38: expected 1 fields, saw 2
# Skipping line 42: expected 1 fields, saw 2
# Skipping line 74: expected 1 fields, saw 3
# Skipping line 88: expected 1 fields, saw 5
# Skipping line 90: expected 1 fields, saw 2
# Skipping line 100: expected 1 fields, saw 2
# Skipping line 118: expected 1 fields, saw 2
# Skipping line 136: expected 1 fields, saw 3
# Skipping line 150: expected 1 fields, saw 2
# Skipping line 160: expected 1 fields, saw 2
# Skipping line 177: expected 1 fields, saw 4
# Skipping line 179: expected 1 fields, saw 4
# Skipping line 183: expected 1 fields, saw 2
# Skipping line 185: expected 1 fields, saw 4
# Skipping line 188: expected 1 fields, saw 2
# Skipping line 210: expected 1 fields, saw 2
# Skipping line 214: expected 1 fields, saw 3
# ...

# %%
df
# Out:
#      https://t.co/e0PYT2kKv8 @arora_pravir of @aptechltd shares his views on #H1B visa
# 0                          "Greetings from MVM Infotech
# 1                          "Greetings from MVM Infotech
# 2                          "Greetings from MVM Infotech
# 3                          "Greetings from MVM Infotech
# 4                                             Hyperion.
# 5                     About... https://t.co/mUa2yZaFl8"
# 6                          "Greetings from MVM Infotech
# 7                                             Hyperion.
# 8                     About... https://t.co/acAEKLttD6"
# 9     "#H1B #visa reforms pose challenges but to ben...
# 10    https://t.co/6g58496fnx… https://t.co/N6cPlw4oNt"
# 11    "#Boomlive highlights RHC founder @iamshalabhk...
# 12                              https://t.co/Q9hMyrqtTN
# 13                  #american… https://t.co/PgwcrhyERu"
# 14    RT @yaxis: #Trumph suggests reforms to help en...
# ...

# %%
my_cols = ["Tweets"]
df.columns = my_cols

# %%
df
# Out:
#                                                  Tweets
# 0                          "Greetings from MVM Infotech
# 1                          "Greetings from MVM Infotech
# 2                          "Greetings from MVM Infotech
# 3                          "Greetings from MVM Infotech
# 4                                             Hyperion.
# 5                     About... https://t.co/mUa2yZaFl8"
# 6                          "Greetings from MVM Infotech
# 7                                             Hyperion.
# 8                     About... https://t.co/acAEKLttD6"
# 9     "#H1B #visa reforms pose challenges but to ben...
# 10    https://t.co/6g58496fnx… https://t.co/N6cPlw4oNt"
# 11    "#Boomlive highlights RHC founder @iamshalabhk...
# 12                              https://t.co/Q9hMyrqtTN
# 13                  #american… https://t.co/PgwcrhyERu"
# 14    RT @yaxis: #Trumph suggests reforms to help en...
# 15    Indian Ph.D. graduate working on lifesaving he...
# ...

# %%
from os import path
from scipy.misc import imread
import matplotlib.pyplot as plt
import random
from wordcloud import WordCloud, STOPWORDS

# %%
text = " ".join(df['Tweets'].values.astype(str))

# %%
 no_urls_no_tags = " ".join([word for word in text.split()
                                if 'http' not in word
                                    and not word.startswith('@')
                                    and word != 'RT'
                                ])

# %%
wc = WordCloud(background_color="black",stopwords=STOPWORDS)
wc.generate(no_urls_no_tags)
plt.imshow(wc)
plt.axis("off")
plt.show()
plt.savefig('h1b.png', dpi=300)
